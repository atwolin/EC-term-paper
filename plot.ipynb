# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

cur_path = os.getcwd()
print(cur_path)

# 读取CSV文件
file_path = cur_path+"/results/-algo*simple_gp*-e*word2vec*-n*10*-p*500*-pc*0.0*-pm*0.0*-g*500*-c*1*-eval*100000.csv"  # 请根据实际文件路径修改
data = pd.read_csv(file_path)

# 绘制图表
plt.figure(figsize=(10, 6))
plt.plot(data['eval_count'], data['avg'], marker='o', linestyle='-')
plt.xlabel('Eval Count')
plt.ylabel('Avg')
plt.title('Anytime Behavior')
plt.grid(True)
plt.show()
# Out:
# /Users/chenyujing/Desktop/yuching/nthu/grade1/2024ec/EC-term-paper

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

cur_path = os.getcwd()
print(cur_path)

# 读取CSV文件
file_path = cur_path+"/results/-algo*simple_gp*-e*word2vec*-n*10*-p*500*-pc*0.0*-pm*0.0*-g*500*-c*1*-eval*100000.csv"  # 请根据实际文件路径修改
data = pd.read_csv(file_path)

# 绘制图表
plt.figure(figsize=(10, 6))
plt.plot(data['eval_count'], data['avg'], marker='o', linestyle='-')
plt.xlabel('Eval Count')
plt.ylabel('Avg')
plt.title('Anytime Behavior')
plt.grid(True)
plt.show()

-algo*simple_gp*-e*glove*-n*10*-p*500*-pc*1.0*-pm*0.0*-g*500*-c*1*-eval*100000*-run*1
